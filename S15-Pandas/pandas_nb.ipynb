# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\roobb\\GitHub\\Python_Mega_Course\\S15-Pandas'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'original', 'pandas.ipynb']

# %%
os.listdir('original/')
# Out:
# ['data.txt',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas

# %%
df1 = pandas.read_csv('original/supermarkets.csv')
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json('original/supermarkets.json')
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pandas.read_excel('original/supermarkets.xlsx', sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv('original/supermarkets-commas.txt')
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv('original/supermarkets-semi-colons.txt', sep=';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pandas.read_csv('original/data.txt', header=None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns = ['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees']
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7 = df6.set_index('ID')
df7
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.loc[2:3, 'City':'Country']
# Out:
#              City             State Country
# ID
# 2   San Francisco          CA 94119     USA
# 3   San Francisco  California 94114     USA

# %%
df7.loc[:, 'City':'Country']
# Out:
#              City             State Country
# ID
# 1   San Francisco          CA 94114     USA
# 2   San Francisco          CA 94119     USA
# 3   San Francisco  California 94114     USA
# 4   San Francisco          CA 94114     USA
# 5   San Francisco        California     USA
# 6   San Francisco          CA 94114     USA

# %%
df7.iloc[1:4, 1:3]
# Out:
#              City             State
# ID
# 2   San Francisco          CA 94119
# 3   San Francisco  California 94114
# 4   San Francisco          CA 94114

# %%
df7.iloc[0, :]
# Out:
# Address       3666 21st St
# City         San Francisco
# State             CA 94114
# Country                USA
# Name               Madeira
# Employees                8
# Name: 1, dtype: object

# %%
df7.drop('City', 1) # 1 - column
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df7.drop(2, 0) # 0 - row
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %%
df7.drop(df7.index[0:3], 0)
# Out:
#             Address           City       State Country        Name  Employees
# ID
# 4      3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop         10
# 5   1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df7.drop(df7.columns[0:3], 1)
# Out:
#    Country         Name  Employees
# ID
# 1      USA      Madeira          8
# 2      USA  Bready Shop         15
# 3      USA  Super River         25
# 4      USA   Ben's Shop         10
# 5      USA      Sanchez         12
# 6      USA   Richvalley         20

# %%
df7['Continent'] = ['North America'] * df7.shape[0]
df7
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df7['Continent'] = df7['Country'] + ', ' + 'North America'
df7
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees           Continent
# ID
# 1           8  USA, North America
# 2          15  USA, North America
# 3          25  USA, North America
# 4          10  USA, North America
# 5          12  USA, North America
# 6          20  USA, North America

# %%
df7.T
# Out:
# ID                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df7_T = df7.T
df7_T[7] = ['My Address', 'My City', 'My State', 'My Country', 'My Name', 'My Employee', 'My Continent']
df7_T
# Out:
# ID                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# ID                          4                   5                   6  \
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df7 = df7_T.T
df7
# Out:
#             Address           City             State     Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114         USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119         USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114         USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114         USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California         USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114         USA   Richvalley
# 7        My Address        My City          My State  My Country      My Name
#
#       Employees           Continent
# ID
# 1             8  USA, North America
# 2            15  USA, North America
# 3            25  USA, North America
# 4            10  USA, North America
# 5            12  USA, North America
# 6            20  USA, North America
# 7   My Employee        My Continent

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
n = nom.geocode('ffkkdkdkfjfjghgjgkkg')
print(n)
# Out:
# None

# %%
n = nom.geocode('3995 23rd St, San Francisco, CA 94114, USA')
n
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.752990821253434, -122.43170235858965, 0.0))

# %%
type(n)
# Out:
# geopy.location.Location

# %%
dir(n)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '_address',
#  '_point',
#  '_raw',
#  '_tuple',
#  'address',
#  'altitude',
#  'latitude',
#  'longitude',
#  'point',
#  'raw']

# %%
n.latitude
# Out:
# 37.752990821253434

# %%
df8 = df6.set_index('ID')
df8
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df8['Full Address'] = df8['Address'] + ', ' + df8['City'] + ', ' + df8['State'] + ', ' + df8['Country']
df8
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees                                       Full Address
# ID
# 1           8         3666 21st St, San Francisco, CA 94114, USA
# 2          15       735 Dolores St, San Francisco, CA 94119, USA
# 3          25  332 Hill St, San Francisco, California 94114, USA
# 4          10         3995 23rd St, San Francisco, CA 94114, USA
# 5          12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df8['Coordinates'] = df8['Full Address'].apply(nom.geocode)
df8
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees                                       Full Address  \
# ID
# 1           8         3666 21st St, San Francisco, CA 94114, USA
# 2          15       735 Dolores St, San Francisco, CA 94119, USA
# 3          25  332 Hill St, San Francisco, California 94114, USA
# 4          10         3995 23rd St, San Francisco, CA 94114, USA
# 5          12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df8['Coordinates']
# Out:
# ID
# 1    (3666 21st St, San Francisco, California, 9411...
# 2    (735 Dolores St, San Francisco, California, 94...
# 3    (332 Hill St, San Francisco, California, 94114...
# 4    (3995 23rd St, San Francisco, California, 9411...
# 5    (1056 Sanchez St, San Francisco, California, 9...
# 6    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df8.Coordinates
# Out:
# ID
# 1    (3666 21st St, San Francisco, California, 9411...
# 2    (735 Dolores St, San Francisco, California, 94...
# 3    (332 Hill St, San Francisco, California, 94114...
# 4    (3995 23rd St, San Francisco, California, 9411...
# 5    (1056 Sanchez St, San Francisco, California, 9...
# 6    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df8.Coordinates[1].latitude
# Out:
# 37.7564496899993

# %%
df8['Latitude'] = df8['Coordinates'].apply(lambda x: x.latitude if x != None else None)
df8['Longitude'] = df8['Coordinates'].apply(lambda x: x.longitude if x != None else None)
df8
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees                                       Full Address  \
# ID
# 1           8         3666 21st St, San Francisco, CA 94114, USA
# 2          15       735 Dolores St, San Francisco, CA 94119, USA
# 3          25  332 Hill St, San Francisco, California 94114, USA
# 4          10         3995 23rd St, San Francisco, CA 94114, USA
# 5          12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df8[['Full Address', 'Latitude', 'Longitude']]
# Out:
#                                          Full Address   Latitude   Longitude
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA  37.756450 -122.429364
# 2        735 Dolores St, San Francisco, CA 94119, USA  37.757796 -122.425597
# 3   332 Hill St, San Francisco, California 94114, USA  37.755648 -122.428803
# 4          3995 23rd St, San Francisco, CA 94114, USA  37.752991 -122.431702
# 5     1056 Sanchez St, San Francisco, California, USA  37.752129 -122.430028
# 6       551 Alvarado St, San Francisco, CA 94114, USA  37.753719 -122.433240
